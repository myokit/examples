# %% [markdown]
# # Logging simulation results

# %% [markdown]
# This example shows different ways to select variables for logging in a simulation, and shows how to read and write simulation results to disk.
#
# For this example we've used [a model of the human atrial AP](https://doi.org/10.1161/CIRCRESAHA.111.253955) by Grandi et al. You can download a copy of the model [here](./models/c).

# %% [markdown]
# ## Specifying variables by name

# %% [markdown]
# We start by loading the [model](https://myokit.readthedocs.io/en/stable/api_core/Model.html) and its associated pacing [protocol](https://myokit.readthedocs.io/en/stable/api_simulations/Protocol.html) and using them to create and run a [simulation](https://myokit.readthedocs.io/en/stable/api_simulations/Simulation.html):

# %%
import myokit

# Load a model, protocol, and script from an mmt file
model, protocol, script = myokit.load('models/c/grandi-2011.mmt')

# Create a simulation
sim = myokit.Simulation(model, protocol)

# Run it
log1 = sim.run(700)

# %% [markdown]
# Now we can take a look at the model code, and find some variables we'd like to plot, for example `membrane.V`, `ical.ICaL` and `ikur.IKur`:

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 9))
plt.subplot(3, 1, 1)
plt.ylabel('V (mV)')
plt.plot(log1['engine.time'], log1['membrane.V'])
plt.subplot(3, 1, 2)
plt.ylabel('ICaL (A/F)')
plt.plot(log1['engine.time'], log1['ical.ICaL'])
plt.subplot(3, 1, 3)
plt.xlabel('Time (ms)')
plt.ylabel('IKur (A/F)')
plt.plot(log1['engine.time'], log1['ikur.IKur'])
plt.show()

# %% [markdown]
# If we know in advance that we only want to plot these variables, we can specify this before running the simulation:

# %%
sim.reset()
log2 = sim.run(700, log=['engine.time', 'membrane.V', 'ical.ICaL', 'ikur.IKur'])

# %% [markdown]
# This will make the simulation log a lot smaller:

# %%
print('Old log size: ' + str(len(log1)))
print('New log size: ' + str(len(log2)))
# Out:
# Old log size: 200
# New log size: 4

# %% [markdown]
# This saves a bit of memory, but can also save some time:

# %%
b = myokit.tools.Benchmarker()
sim.reset()
sim.run(10 * 1000)
print('With all variables: ' + str(b.time()) + ' seconds')
b.reset()
sim.reset()
sim.run(10 * 1000, log=['engine.time', 'membrane.V', 'ical.ICaL', 'ikur.IKur'])
print('With four variables: ' + str(b.time()) + ' seconds')
b.reset()
sim.reset()
sim.run(10 * 1000, log=[])
print('With zero variables: ' + str(b.time()) + ' seconds')
# Out:
# With all variables: 0.09026705699943705 seconds
# With four variables: 0.02699916200072039 seconds
# With zero variables: 0.022854347997053992 seconds

# %% [markdown]
# ## Logging derivatives

# %% [markdown]
# Derivatives of state variables can also be logged.
# These are specified using the syntax `dot(x)`, where `x` is the name of the state variable:

# %%
sim.reset()
log = sim.run(200, log=['engine.time', 'membrane.V', 'dot(membrane.V)'])

plt.figure()
plt.subplot(2, 1, 1)
plt.xlim(45, 60)
plt.ylabel('V (mV)')
plt.plot(log['engine.time'], log['membrane.V'])
plt.subplot(2, 1, 2)
plt.xlim(45, 60)
plt.ylabel('dV/dt (mV/ms)')
plt.plot(log['engine.time'], log['dot(membrane.V)'])
plt.show()

# %% [markdown]
# ## Using logging flags

# %% [markdown]
# In addition to specifying variables by name, we can use integer 'flags' to specify groups of variables.
# For example, to log only state variables, use the `LOG_STATE` flag:

# %%
sim.reset()
log = sim.run(1000, log=myokit.LOG_STATE)

print(model.count_states())
print(len(log))
# Out:
# 40
# 40

# %% [markdown]
# Typically, we'll also want to log time though, which we can achieve with:

# %%
sim.reset()
log = sim.run(600, log=myokit.LOG_STATE + myokit.LOG_BOUND)

print(model.count_states())
print(len(log))
# Out:
# 40
# 42

# %% [markdown]
# The `LOG_BOUND` flag tells the simulator to log any variable "bound" to external inputs: in this case the time variable and the variable that's used to create a pacing signal. These variables are called "bound variables in Myokit (see [here](https://myokit.readthedocs.io/en/stable/syntax/model.html#interfacing-with-the-outside-world)).

# %% [markdown]
# What about currents?
# These are not state variables or bound variables.
# From a mathematical point of view, they are simply part of the equations to calculate the state variable derivatives.
# In Myokit we call any such variable an "intermediate variable", and we can log all intermediate variables using `LOG_INTER`:

# %%
sim.reset()
log = sim.run(600, log=myokit.LOG_INTER + myokit.LOG_BOUND)

print(len(log))
# Out:
# 120

# %%
plt.figure()
plt.xlabel('Time (ms)')
plt.ylabel('Ito (A/F)')
plt.plot(log['engine.time'], log['ito.Ito'])
plt.show()

# %% [markdown]
# The full list of flags is given [here](https://myokit.readthedocs.io/en/stable/api_simulations/DataLog.html#myokit.prepare_log).

# %% [markdown]
# ## Continuing a previous simulation

# %% [markdown]
# A final option for the `log` argument is to pass in an existing simulation log. In this case, the newly logged entries will be appended to the ones already in the log.
#
# Let's run the first 100ms of a simulation:

# %%
sim.reset()

log1 = sim.run(100)

plt.figure()
plt.xlabel('Time (ms)')
plt.ylabel('Membrane potential (mV)')
plt.plot(log1['engine.time'], log1['membrane.V'])
plt.show()

# %% [markdown]
# We can run again, to create a second log, and plot both:

# %%
log2 = sim.run(500)

plt.figure()
plt.xlabel('Time (ms)')
plt.ylabel('Membrane potential (mV)')
plt.plot(log1['engine.time'], log1['membrane.V'], label='First simulation')
plt.plot(log2['engine.time'], log2['membrane.V'], label='Second simulation')
plt.show()

# %% [markdown]
# But we can also _pass in the original log_, and then the new results will be appended to the old one:

# %%
sim.reset()

log = sim.run(100)
log = sim.run(500, log=log)

plt.figure()
plt.xlabel('Time (ms)')
plt.ylabel('Membrane potential (mV)')
plt.plot(log['engine.time'], log['membrane.V'])
plt.show()

# %% [markdown]
# This can be useful if we want to make changes during a simulation:

# %%
sim.reset()

sim.set_constant('ical.scaling', 1)
log = sim.run(75)
sim.set_constant('ical.scaling', 0)
log = sim.run(50, log=log)
sim.set_constant('ical.scaling', 1)
log = sim.run(475, log=log)

plt.figure()
plt.xlabel('Time (ms)')
plt.ylabel('Membrane potential (mV)')
plt.plot(log['engine.time'], log['membrane.V'])
plt.axvline(75, linestyle='--', color='gray', alpha=0.3)
plt.axvline(225, linestyle='--', color='gray', alpha=0.3)
plt.show()

# %% [markdown]
# _(In this example, the model we used has a variable "ical.scaling" that lets us scale the L-type calcium current. We can use the_ [set_constant()](https://myokit.readthedocs.io/en/stable/api_simulations/Simulation.html#myokit.Simulation.set_constant) _method to change any model constants/parameters in a simulation.)_

# %% [markdown]
# ## Selecting which points to log

# %% [markdown]
# By default, myokit's Simulation class logs all points visited by the ODE integrating algorithm. This is quite useful for plotting, because it means there will be lots of points in rapidly changing areas, and many fewer points in areas where change is slow:

# %%
sim.reset()
log = sim.run(1000)

plt.figure(figsize=(14, 6))
plt.subplot(2, 1, 1)
plt.xlabel('Time (ms)')
plt.ylabel('Membrane potential (mV)')
plt.plot(log['engine.time'], log['membrane.V'], 'x-')
plt.subplot(2, 1, 2)
plt.xlabel('Time (ms)')
plt.ylabel('Membrane potential (mV)')
plt.plot(log['engine.time'], log['membrane.V'], 'x-')
plt.xlim(48, 53)
plt.show()

# %% [markdown]
# However, in some cases you'll want to control the logged points instead.
# For example to get a regular log interval.
# One possible way to do this is by post-processing an existing log with [`DataLog.regularize`](https://myokit.readthedocs.io/en/stable/api_simulations/DataLog.html#myokit.DataLog.regularize):

# %%
reg = log.regularize(dt=0.1)

plt.figure(figsize=(14, 3))
plt.xlabel('Time (ms)')
plt.ylabel('Membrane potential (mV)')
plt.plot(reg['engine.time'], reg['membrane.V'], 'x-')
plt.xlim(48, 53)
plt.show()

# %% [markdown]
# This method finds points close to the regular ones, and then uses linear interpolation.
# A faster and more accurate method is to use the Simulation class's `log_interval` argument:

# %%
sim.reset()
log = sim.run(1000, log_interval=0.1)

plt.figure(figsize=(14, 3))
plt.xlabel('Time (ms)')
plt.ylabel('Membrane potential (mV)')
plt.plot(log['engine.time'], log['membrane.V'], 'x-')
plt.xlim(48, 53)
plt.show()

# %% [markdown]
# In this method, the interpolation is performed by the ODE integrator, which means it can be a 4th or 5th order linear interpolation (rather than a 1st order one). This requires very little overhead, as the solver calculates these approximations already as part of the integration process.

# %% [markdown]
# Finally, if you want full control over which points are logged, you can use the `log_times` argument:

# %%
import numpy as np
sim.reset()
log1 = sim.run(1000, log_times=np.arange(0, 1000, 0.1))

sim.reset()
log2 = sim.run(1000, log_times=np.arange(0, 1000, 0.3))

plt.figure(figsize=(14, 3))
plt.xlabel('Time (ms)')
plt.ylabel('Membrane potential (mV)')
plt.plot(log1['engine.time'], log1['membrane.V'], 'x-')
plt.plot(log2['engine.time'], log2['membrane.V'], 'o')
plt.xlim(48, 53)
plt.show()

# %% [markdown]
# ## Storing results to disk

# %% [markdown]
# Instead of plotting or analysing results directly, [DataLog](https://myokit.readthedocs.io/en/stable/api_simulations/DataLog.html) objects returned by simulations can be written to the filesystem.

# %% [markdown]
# The _fastest_ way to do this is to use the DataLog's `save` and `load` methods:

# %%
# Run a simulation and store the results
sim.reset()
log = sim.run(1000, log=['engine.time', 'calcium.Ca_i'])
log.save('data/my_simulation.zip')
del(log)

# Load and plot the results
log = myokit.DataLog.load('data/my_simulation.zip')

plt.figure()
plt.xlabel('Time (ms)')
plt.ylabel('[Ca2+]i (mM)')
plt.plot(log['engine.time'], log['calcium.Ca_i'])
plt.show()

# %% [markdown]
# The file format used by `save` and `load` is a compressed binary file, which is a very efficient way to store the data, but not a very _interoperable_ one.
#
# An alternative is to use [CSV files](https://en.wikipedia.org/wiki/Comma-separated_values), which can be written and read by a huge number of other tools:

# %%
# Save to disk
log.save_csv('data/my_simulation.csv')
del(log)

# Load from disk and plot
log = myokit.DataLog.load_csv('data/my_simulation.csv')
plt.figure()
plt.xlabel('Time (ms)')
plt.ylabel('[Ca2+]i (mM)')
plt.plot(log['engine.time'], log['calcium.Ca_i'])
plt.show()

# %% [markdown]
# Because of this compatibility with other tools, storing to CSV is the most common way to save and load Myokit data. However, in situations where speed or disk space is important (for example when writing very large simulation logs to disk, or when saving and loading repeatedly), using the binary format can be a more efficient choice.
